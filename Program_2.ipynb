# %% [markdown]
# <a href="https://colab.research.google.com/github/likithams09/deep-learning-with-python/blob/main/Program_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PROGRAM 2: MNIST Classification with dataset augmentation

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import (
Input,
Flatten,
Dense,
RandomRotation,
RandomTranslation,
RandomZoom
)

# %% [markdown]
# Load MNIST dataset

# %%
(x_train, y_train), (x_test, y_test) = \
 tf.keras.datasets.mnist.load_data()
print("Training images:", x_train.shape)
print("Training labels:", y_train.shape)
print("Test images:", x_test.shape)
print("Test labels:", y_test.shape)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training images: (60000, 28, 28)
# Training labels: (60000,)
# Test images: (10000, 28, 28)
# Test labels: (10000,)

# %% [markdown]
# Normalize pixel values

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# %% [markdown]
# Create DATA AUGMENTATION

# %%
data_augmentation = Sequential([
# Slightly rotate the image
RandomRotation(0.1),
# Slightly move the image
RandomTranslation(
height_factor=0.1,
width_factor=0.1
),
# Slightly zoom the image
RandomZoom(0.1)
])

# %% [markdown]
#  Create Deep Neural Network

# %%
model = Sequential([
# INPUT LAYER
Input(shape=(28, 28)),
# DATA AUGMENTATION
data_augmentation,
# Convert 28 x 28 into 784 values
Flatten(),
# HIDDEN LAYER 1
Dense(128, activation="relu"),
# HIDDEN LAYER 2
Dense(64, activation="relu"),
# OUTPUT LAYER
Dense(10, activation="softmax")
])

# %% [markdown]
#  Display model architecture

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           650 │
# ...

# %% [markdown]
#  Compile the model

# %%
model.compile(
optimizer="sgd",
loss="sparse_categorical_crossentropy",
metrics=["accuracy"]
)

# %% [markdown]
#  Train the model

# %%
history = model.fit(
x_train,
y_train,
epochs=5,
batch_size=128,
validation_split=0.1
)
# Out:
# Epoch 1/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.1053 - loss: 2.3098 - val_accuracy: 0.1095 - val_loss: 2.3237
# Epoch 2/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.1069 - loss: 2.3051 - val_accuracy: 0.1323 - val_loss: 2.3073
# Epoch 3/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.1061 - loss: 2.3053 - val_accuracy: 0.1590 - val_loss: 2.2951
# Epoch 4/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.1082 - loss: 2.3043 - val_accuracy: 0.1608 - val_loss: 2.2853
# Epoch 5/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.1110 - loss: 2.3033 - val_accuracy: 0.1683 - val_loss: 2.2788

# %% [markdown]
# Evaluate on TEST dataset

# %%
test_loss, test_accuracy = model.evaluate(
x_test,
y_test,
verbose=0
)

# %%
print("Test Loss     :", test_loss)
print("Test Accuracy :", test_accuracy)
# Out:
# Test Loss     : 2.2776546478271484
# Test Accuracy : 0.16539999842643738
